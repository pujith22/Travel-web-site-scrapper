# %%
import requests
from bs4 import BeautifulSoup
import re

#for comparing text of 2 places (own logic)
def compareString(str1,str2):
    count = 0
    string1 = str1.lower()
    string2 = str2.lower()
    for i in list(string1.split()):
        for j in list(string2.split()):
            if i==j:
                count = count + 1
    return (2*count)/(len(string1.split())+len(string2.split()))

def printParagraph(state,inp):
    url1="http://www.transindiatravels.com/"+state+"/"+inp+"/"+"tourist-places-to-visit-in-"+inp
    url2="http://www.transindiatravels.com/"+state+"/"+"tourist-places-to-visit-in-"+state
    if inp==state:
        url3 = url2
    else:
        url3 = url1    
    html = requests.get(url3).text
    #soup = BeautifulSoup(driver.page_source, 'lxml')
    soup = BeautifulSoup(html)
    all_links = soup.find('article')
    sp1 = all_links.find_all('h2')
    sp2 = all_links.find_all('p')
    i=0
    #for i in range(len(sp1)):
        #print(sp1[i].text)
    for i in range(len(sp2)):
        print(sp2[i].text)
        print()

if __name__=="__main__":
    #for taking input from the user asking the city he wanted to visit
    state = input("Enter the state you want to visit: ")
    temp = ""
    for i in state.split():
        temp += i+"-"
    state = temp[:-1]
    temp = ""
    inp = input("Enter the City you want to Visit: ")
    for i in inp.split():
        temp += i+"-"
    inp = temp[:-1]
    #temporary list and dictionary objects to be used in the program later
    places = []
    #for storing count of occurance of places from different travel web-sites
    count_dict = {}
    #List for removing unnecessary places like airport, hotel etc.
    unnessaryLis = ["airport","airline","bed","medical","hospitals","pub","taxi","residency","pvr","mcdonald","tea","chaat","chat","donald","kfc","metro","emergency","lodge","stay","helpline","g","zealand","korea","nepal","mongolia","rwanda","poland","finland","utter","side","[email","deluxe","palace","states","united","canada","vietnam","thailand","arabia","malaysia","japan","emirates","pakistan","japan","italy","indonesia","greece","germany","france","china","brazil","australia","clinic","lanka","netherlands","israel","iran","georgia","russia","egypt","belgium","argentina","afghanistan","djibouti","czech","terminus","terminal","enquiry","chemist","guest","cafe","ambulance","hospital","cab","cabs","railways","station","hotel","restaurant","inn","break","police","airline","travels"]

    #list of links we want to scrape for getting data with their required parameters.
    url =[["https://wikitravel.org/en/"+inp,"span","fn org"],["https://en.wikivoyage.org/wiki/"+inp,"span","fn org listing-name",0],["https://www.holidify.com/places/"+inp+"/sightseeing-and-things-to-do.html","h2","card-heading"],["http://www.transindiatravels.com/"+state+"/"+inp+"/tourist-places-to-visit-in-"+inp,"h2",""]]

    #traversing the links and getting url requests and having data according to required format.
    for link in url:
        #getting html object
        html = requests.get(link[0]).text
        soup = BeautifulSoup(html)
        all_links = soup.find_all(link[1],class_=link[2])
        for link1 in all_links:
            required = True
            temp = list((link1.text).split())
            for i in temp:
                if i.lower() in unnessaryLis:
                    required = False
                    break
            if(required):
                placeName = link1.text
                for i in range(len(placeName)):
                    if ((placeName[i]>='a' and placeName[i]<='z') or (placeName[i]>='A' and placeName[i]<='Z')):
                        placeName = placeName[i:]
                        break
                places.append(placeName)
    #print(places)
    
    for place in places:
        temp = place
        delKey = ''
        prevCount = 0
        for key in count_dict.keys():
            if compareString(key,place)>=0.4:
                # If the length of the previous key is greter than the new place name
                # Replace the old key with new one.
                if(len(key)>len(place)):
                    delKey = key
                    prevCount = count_dict[key]                    
                else:
                    temp = key
                    break
        try:
            if delKey == '':
                count_dict[temp] += 1
            else:
                del(count_dict[delKey])
                count_dict[place] = prevCount+1
        except:
            count_dict[temp] = 0
    #print(count_dict)
    
    sorted_dict = sorted(((value, key) for (key,value) in count_dict.items()),reverse=True)
    j = 1
    for i in sorted_dict:
        if j<41:
            print(j,". ",end="")
            print(i[1])
        else:
            break
        j += 1
    printParagraph(state,inp)
# Out:
# Enter the state you want to visit: goa
# Enter the City you want to Visit: goa
# 1 . Baga Beach
# 2 . Old Goa
# 3 . German consulate
# 4 . Butterfly Conservatory Of Goa
# 5 . Savoi Plantation
# 6 . Mambos, Calangute
# 7 . Bondla Wildlife Sanctuary
# 8 . Water Sports in Goa
# 9 . Volunteering Goa
# 10 . Fort Aguada
# 11 . Cookly Indian Vegetarian & Vegan Cooking Class
# 12 . Church of St. Cajetan
# 13 . Centre for Responsible Tourism (CRT)
# 14 . Vasco da Gama
# 15 . The Lost Hostel, Goa
# 16 . The Garça Branca Ayurvedic Botanical Garden
# 17 . Support Local charity work
# 18 . Sri Mahadeva Temple
# 19 . Spa and Massages
# 20 . Se Cathedral
# 21 . Reserve Bank of India's Foreign Exchange Department
# 22 . Querim Beach and Tiracol Fort
# 23 . Panaji
# 24 . Monastery Of St Augustine
# 25 . Mollem National Park
# 26 . Margao
# 27 . Mapusa
# 28 . Karai Garden
# 29 . Indo Portuguese Friendship Society
# 30 . Great Live Music 2014
# 31 . Fundação Oriente Delegation in India'
# ...

# %%
def compareString(string1,string2):
    count = 0
    for i in list(string1.split()):
        print(i)
        for j in list(string2.split()):
            if i==j:
                count = count + 1
    return (2*count)/(len(string1.split())+len(string2.split()))
print(compareString("pujith","pujith sai kumar"))
# Out:
# pujith
# 0.5

# %%
["https://en.wikivoyage.org/wiki/"+inp,"span","fn org listing-name",0]
["http://www.transindiatravels.com/"+state+"/"+inp+"/tourist-places-to-visit-in-"+inp,"h2","",3]
[]"http://www.transindiatravels.com/goa/tourist-places-to-visit-in-goa"

# %%
import requests
from bs4 import BeautifulSoup
import re
#inp = input("Enter your City: ")
#url="https://www.tripadvisor.in/Search?singleSearchBox=true&geo=1&searchNearby=&pid=3826&redirect=&startTime=1573727111738&uiOrigin=MASTHEAD&q=lucknow&supportedSearchTypes=find_near_stand_alone_query&enableNearPage=true&returnTo=https%253A__2F____2F__www__2E__tripadvisor__2E__in__2F__&searchSessionId=C493545290975B1E4CFD5B29F9806A2F1573727090496ssid&social_typeahead_2018_feature=true&sid=C493545290975B1E4CFD5B29F9806A2F1573727117185&blockRedirect=true"
state = input("Enter state:")
state = state.lower()
inp = input("Enter the city you wanted to travel: ")
inp = inp.lower()

# %%
import requests
from bs4 import BeautifulSoup
import re
#inp = input("Enter your City: ")
#url="https://www.tripadvisor.in/Search?singleSearchBox=true&geo=1&searchNearby=&pid=3826&redirect=&startTime=1573727111738&uiOrigin=MASTHEAD&q=lucknow&supportedSearchTypes=find_near_stand_alone_query&enableNearPage=true&returnTo=https%253A__2F____2F__www__2E__tripadvisor__2E__in__2F__&searchSessionId=C493545290975B1E4CFD5B29F9806A2F1573727090496ssid&social_typeahead_2018_feature=true&sid=C493545290975B1E4CFD5B29F9806A2F1573727117185&blockRedirect=true"
state = input("Enter state:")
inp = input("Enter the city you wanted to travel: ")
url1="http://www.transindiatravels.com/"+state+"/"+inp+"/"+"tourist-places-to-visit-in-"+inp
url2="http://www.transindiatravels.com/"+state+"/"+"tourist-places-to-visit-in-"+state
if inp==state:
    url = url2
else:
    url = url1    
html = requests.get(url).text
#soup = BeautifulSoup(driver.page_source, 'lxml')
soup = BeautifulSoup(html)
all_links = soup.find('article')
sp1 = soup.find_all('h2')
sp2 = all_links.find_all('p')
i=0
for i in range(len(sp2)):
    print(sp2[i].text)
    print()

# %%
import requests
from bs4 import BeautifulSoup
import re
#inp = input("Enter your City: ")
#url="https://www.tripadvisor.in/Search?singleSearchBox=true&geo=1&searchNearby=&pid=3826&redirect=&startTime=1573727111738&uiOrigin=MASTHEAD&q=lucknow&supportedSearchTypes=find_near_stand_alone_query&enableNearPage=true&returnTo=https%253A__2F____2F__www__2E__tripadvisor__2E__in__2F__&searchSessionId=C493545290975B1E4CFD5B29F9806A2F1573727090496ssid&social_typeahead_2018_feature=true&sid=C493545290975B1E4CFD5B29F9806A2F1573727117185&blockRedirect=true"
inp = input("Enter the city you wanted to travel: ")
url="https://www.yatra.com/india-tourism/attractions-in-"+inp 
html = requests.get(url).text
#soup = BeautifulSoup(driver.page_source, 'lxml')
soup = BeautifulSoup(html)
all_links = soup.find_all('div',class_="f1.w90")
print(all_links)
# Out:
# Enter the city you wanted to travel: lucknow
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# c:\users\pujith sai kumar k\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     602                                                   body=body, headers=headers,
# --> 603                                                   chunked=chunked)
#     604
#
# c:\users\pujith sai kumar k\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
# ...

# %%
def printParagraph(state,inp):
    url1="http://www.transindiatravels.com/"+state+"/"+inp+"/"+"tourist-places-to-visit-in-"+inp
    url2="http://www.transindiatravels.com/"+state+"/"+"tourist-places-to-visit-in-"+state
    if inp==state:
        url3 = url2
    else:
        url3 = url1    
    html = requests.get(url3).text
    #soup = BeautifulSoup(driver.page_source, 'lxml')
    soup = BeautifulSoup(html)
    all_links = soup.find('article')
    sp1 = all_links.find_all('h2')
    sp2 = all_links.find_all('p')
    i=0
    #for i in range(len(sp1)):
        #print(sp1[i].text)
    for i in range(len(sp2)):
        print(sp2[i].text)
        print()
